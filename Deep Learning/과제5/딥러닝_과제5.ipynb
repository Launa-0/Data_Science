# %% [markdown]
# #포켓몬 이름 맞추기
# 본 과제는 2점 만점이며, 정확도(Accuracy)를 평가 지표로 사용합니다.
# Baseline보다 높은 정확도 달성: 2.0점
# Baseline의 정확도와 동일(소수 5 번째 자리까지)하거나, 낮은 정확도 달성: 1.0점
# 미제출: 0점
# (주의) 허용할 수 없을 정도로 낮은 정확도로 기록된 것도 미제출로 간주될 수 있습니다.
#
# 현재 Baseline은 Keras 라이브러리를 활용해 구성한 합성곱 신경망 모델을 활용해 도출됐습니다.
# 데이터 세트 분할 시, random_state 값은 42로 지정했습니다.
# 수업 시간에 다뤘던 합성곱 신경망 모델 구조 설계 및 하이퍼파라미터와 관련된 내용을 복습하고, 과제 5를 해결해 봅시다.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# 1. 데이터 로드
data = np.load("train.npz")
x = data["x"]      # (292, H, W, 3) 이거나 (292, H, W)
y = data["y"]      # 문자열 라벨 (포켓몬 이름)

print("x shape before:", x.shape)

# 2. x 전처리 (채널 처리 + 정규화)
x = x.astype("float32") / 255.0

if x.ndim == 3:
    # (N, H, W) -> (N, H, W, 1)
    x = x[..., np.newaxis]
elif x.ndim == 4:
    # (N, H, W, C) 이미 채널 있음 -> 그대로 사용
    pass
else:
    raise ValueError(f"예상 밖의 x.ndim: {x.ndim}")

print("x shape after:", x.shape)  # 여기서 첫 번째 차원은 반드시 292여야 함

# 3. 레이블 인코딩
le = LabelEncoder()
y_encoded = le.fit_transform(y)          # 예: bulbasaur -> 0, charmander -> 1 ...
num_classes = len(le.classes_)
y_onehot = to_categorical(y_encoded, num_classes=num_classes)

# 4. train / validation 분할
x_train, x_val, y_train, y_val = train_test_split(
    x, y_onehot,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded   # stratify는 y_onehot 말고 y_encoded로!
)
# Out:
# x shape before: (292, 200, 200, 3)
# x shape after: (292, 200, 200, 3)

# %%
# 5. CNN 모델 구성
model = Sequential([
    Conv2D(32, (3,3), activation='relu', padding='same', input_shape=x_train.shape[1:]),
    MaxPooling2D(2,2),
    BatchNormalization(),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    MaxPooling2D(2,2),
    BatchNormalization(),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    MaxPooling2D(2,2),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    batch_size=16,
    callbacks=[es],
    verbose=1
)

val_loss, val_acc = model.evaluate(x_val, y_val, verbose=0)
print("Validation Accuracy:", val_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3233 - loss: 15.4547 - val_accuracy: 0.1864 - val_loss: 2.8151
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.7332 - loss: 5.8713 - val_accuracy: 0.2881 - val_loss: 3.9920
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8057 - loss: 4.1552 - val_accuracy: 0.2542 - val_loss: 6.7910
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8675 - loss: 2.0574 - val_accuracy: 0.2712 - val_loss: 8.9515
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.8617 - loss: 2.2112 - val_accuracy: 0.1186 - val_loss: 11.9365
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.8782 - loss: 1.9275 - val_accuracy: 0.1525 - val_loss: 17.6989
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9079 - loss: 2.0307 - val_accuracy: 0.1186 - val_loss: 14.8547
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9074 - loss: 3.1340 - val_accuracy: 0.2373 - val_loss: 17.3465
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.9317 - loss: 1.5051 - val_accuracy: 0.3390 - val_loss: 17.6605
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9444 - loss: 1.2878 - val_accuracy: 0.2373 - val_loss: 24.3506
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9108 - loss: 1.4326 - val_accuracy: 0.2542 - val_loss: 24.4433
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9416 - loss: 1.1401 - val_accuracy: 0.2373 - val_loss: 18.1370
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9286 - loss: 0.8597 - val_accuracy: 0.2373 - val_loss: 20.5791
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9788 - loss: 0.3311 - val_accuracy: 0.1864 - val_loss: 27.2618
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9146 - loss: 1.1253 - val_accuracy: 0.2034 - val_loss: 18.6673
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9646 - loss: 0.3894 - val_accuracy: 0.3729 - val_loss: 14.8642
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9768 - loss: 0.3653 - val_accuracy: 0.5254 - val_loss: 10.2739
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9673 - loss: 0.8712 - val_accuracy: 0.2373 - val_loss: 25.3234
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 0.9508 - loss: 0.4484 - val_accuracy: 0.3220 - val_loss: 20.9800
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9836 - loss: 0.2356 - val_accuracy: 0.4237 - val_loss: 14.2327
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.9729 - loss: 0.2561 - val_accuracy: 0.4746 - val_loss: 10.4263
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9963 - loss: 0.3550 - val_accuracy: 0.4746 - val_loss: 10.0434
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9440 - loss: 0.4229 - val_accuracy: 0.5593 - val_loss: 9.9700
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9469 - loss: 1.7333 - val_accuracy: 0.5424 - val_loss: 9.8090
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 0.9431 - loss: 1.6814 - val_accuracy: 0.6949 - val_loss: 8.4949
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9659 - loss: 1.2766 - val_accuracy: 0.5932 - val_loss: 8.4882
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9685 - loss: 0.5098 - val_accuracy: 0.7797 - val_loss: 1.9690
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.9681 - loss: 1.1842 - val_accuracy: 0.7966 - val_loss: 6.3929
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9613 - loss: 0.7388 - val_accuracy: 0.8475 - val_loss: 5.9384
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9549 - loss: 1.5956 - val_accuracy: 0.6780 - val_loss: 6.3764
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9581 - loss: 0.6900 - val_accuracy: 0.6102 - val_loss: 8.7972
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.9648 - loss: 0.2304 - val_accuracy: 0.6271 - val_loss: 7.9823
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9765 - loss: 0.4177 - val_accuracy: 0.7627 - val_loss: 6.1063
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9655 - loss: 1.4555 - val_accuracy: 0.7797 - val_loss: 7.7402
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9780 - loss: 0.3299 - val_accuracy: 0.7288 - val_loss: 8.6395
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 0.9712 - loss: 0.6236 - val_accuracy: 0.7288 - val_loss: 11.9694
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9722 - loss: 1.0241 - val_accuracy: 0.6441 - val_loss: 14.2884
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 0.9916 - loss: 0.2487 - val_accuracy: 0.6949 - val_loss: 14.5726
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9608 - loss: 0.7283 - val_accuracy: 0.7627 - val_loss: 12.3635
# Validation Accuracy: 0.8474576473236084

# %%
# 전체 데이터로 다시 학습 (선택)
model_final = model  # 그냥 이 모델 써도 되고, 원하면 x,y 전체로 다시 fit 해도 됨

# test 데이터 로드
test_data = np.load("test.npz")
x_test = test_data["x"].astype("float32") / 255.0

if x_test.ndim == 3:
    x_test = x_test[..., np.newaxis]
elif x_test.ndim == 4:
    pass
else:
    raise ValueError(f"예상 밖의 x_test.ndim: {x_test.ndim}")

# 예측
probs = model_final.predict(x_test)
pred_idx = probs.argmax(axis=1)
pred_labels = le.inverse_transform(pred_idx)  # 숫자를 다시 포켓몬 이름으로

# submission.csv에 쓰기
df = pd.read_csv("submission.csv")
df.dropna(axis=1, inplace=True)

df["result"] = pred_labels
df.to_csv("new_submission.csv", index=False)
print("✅ new_submission.csv 저장 완료")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step
# ✅ new_submission.csv 저장 완료

# %% [markdown]
# #2트

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# 1) train.npz 로드
data = np.load("train.npz")
x = data["x"]      # (292, H, W) or (292, H, W, 3)
y = data["y"]      # 문자열 포켓몬 이름

print("x shape:", x.shape)
print("y shape:", y.shape)

# 2) 레이블 인코딩 (문자열 -> 숫자)
le = LabelEncoder()
y_idx = le.fit_transform(y)
num_classes = len(le.classes_)
print("클래스 개수:", num_classes)

# 3) 이미지 전처리
#   - grayscale이면 채널 추가
#   - 3채널 아니면 3채널로 맞추기
x = x.astype("float32")

if x.ndim == 3:
    # (N, H, W) -> (N, H, W, 1)
    x = x[..., np.newaxis]

if x.shape[-1] == 1:
    # (N, H, W, 1) -> (N, H, W, 3)
    x = np.repeat(x, 3, axis=-1)

print("x after channel fix:", x.shape)

# EfficientNet 입력 크기 (적당히 128 정도로)
IMG_SIZE = 128
x = tf.image.resize(x, (IMG_SIZE, IMG_SIZE)).numpy()

# 4) train / valid split (random_state=42 필수)
x_train, x_val, y_train, y_val = train_test_split(
    x, y_idx, test_size=0.2, random_state=42, stratify=y_idx
)

print("train:", x_train.shape, "valid:", x_val.shape)
# Out:
# x shape: (292, 200, 200, 3)
# y shape: (292,)
# 클래스 개수: 8
# x after channel fix: (292, 200, 200, 3)
# train: (233, 128, 128, 3) valid: (59, 128, 128, 3)

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, Input

# 데이터 증강 레이어
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# 입력 정의
inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

x_in = data_augmentation(inputs)
x_in = preprocess_input(x_in)

base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_tensor=x_in
)
base_model.trainable = False  # 1단계: 상단만 학습

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
outputs = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

es = EarlyStopping(
    monitor="val_accuracy",
    patience=10,
    restore_best_weights=True
)
rlr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-5
)

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    batch_size=16,
    callbacks=[es, rlr],
    verbose=1
)

val_loss, val_acc = model.evaluate(x_val, y_val, verbose=0)
print("1단계 (frozen base) Validation Accuracy:", val_acc)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 128, 128,  │          0 │ input_layer_1[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 128, 128,  │          0 │ sequential_1[0][… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 128, 128,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 128, 128,  │          0 │ normalization[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 129, 129,  │          0 │ rescaling_1[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 64, 64,    │        864 │ stem_conv_pad[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 64, 64,    │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 64, 64,    │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 64, 64,    │        288 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 64, 64,    │        128 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 64, 64,    │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 64, 64,    │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 64, 64,    │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 64, 64,    │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 64, 64,    │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 64, 64,    │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 64, 64,    │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 65, 65,    │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 32, 32,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 32, 32,    │        384 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 32, 32,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 32, 32,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 32, 32,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 32, 32,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 32, 32,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 32, 32,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 32, 32,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 32, 32,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 32, 32,    │        576 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 32, 32,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 32, 32,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 32, 32,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 32, 32,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 32, 32,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 32, 32,    │          0 │ block2b_drop[0][… │
# │                     │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 32, 32,    │      3,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 32, 32,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 32, 32,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 35, 35,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 16, 16,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 16, 16,    │        576 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 16, 16,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 16, 16,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 16, 16,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 16, 16,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 16, 16,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 16, 16,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 16, 16,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 16, 16,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 16, 16,    │        960 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 16, 16,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 16, 16,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 16, 16,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 16, 16,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 16, 16,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 16, 16,    │          0 │ block3b_drop[0][… │
# │                     │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 16, 16,    │      9,600 │ block3b_add[0][0] │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 16, 16,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 16, 16,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 17, 17,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 8, 8, 240) │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 8, 8, 240) │        960 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 8, 8, 240) │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 8, 8, 240) │          0 │ block4a_activati… │
# │ (Multiply)          │                   │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 8, 8, 80)  │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 8, 8, 80)  │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 8, 8, 480) │     38,400 │ block4a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 8, 8, 480) │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 8, 8, 480) │          0 │ block4b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 8, 8, 480) │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 8, 8, 480) │      1,920 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 8, 8, 480) │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 8, 8, 480) │          0 │ block4b_activati… │
# │ (Multiply)          │                   │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 8, 8, 80)  │     38,400 │ block4b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 8, 8, 80)  │        320 │ block4b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 8, 8, 80)  │          0 │ block4b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 8, 8, 80)  │          0 │ block4b_drop[0][… │
# │                     │                   │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 8, 8, 480) │     38,400 │ block4b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 8, 8, 480) │      1,920 │ block4c_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 8, 8, 480) │          0 │ block4c_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 8, 8, 480) │      4,320 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 8, 8, 480) │      1,920 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 8, 8, 480) │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 480)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 480) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 8, 8, 480) │          0 │ block4c_activati… │
# │ (Multiply)          │                   │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 8, 8, 80)  │     38,400 │ block4c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 8, 8, 80)  │        320 │ block4c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 8, 8, 80)  │          0 │ block4c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 8, 8, 80)  │          0 │ block4c_drop[0][… │
# │                     │                   │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 8, 8, 480) │     38,400 │ block4c_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 8, 8, 480) │      1,920 │ block5a_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 8, 8, 480) │          0 │ block5a_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv      │ (None, 8, 8, 480) │     12,000 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 8, 8, 480) │      1,920 │ block5a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 8, 8, 480) │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 480)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 480) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 480) │     10,080 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 8, 8, 480) │          0 │ block5a_activati… │
# │ (Multiply)          │                   │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 8, 8, 112) │     53,760 │ block5a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 8, 8, 112) │        448 │ block5a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 8, 8, 672) │     75,264 │ block5a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 8, 8, 672) │      2,688 │ block5b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 8, 8, 672) │          0 │ block5b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv      │ (None, 8, 8, 672) │     16,800 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 8, 8, 672) │      2,688 │ block5b_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 8, 8, 672) │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 672)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 672) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 8, 8, 672) │          0 │ block5b_activati… │
# │ (Multiply)          │                   │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 8, 8, 112) │     75,264 │ block5b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 8, 8, 112) │        448 │ block5b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 8, 8, 112) │          0 │ block5b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 8, 8, 112) │          0 │ block5b_drop[0][… │
# │                     │                   │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 8, 8, 672) │     75,264 │ block5b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 8, 8, 672) │      2,688 │ block5c_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 8, 8, 672) │          0 │ block5c_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv      │ (None, 8, 8, 672) │     16,800 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 8, 8, 672) │      2,688 │ block5c_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 8, 8, 672) │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 672)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 672) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 8, 8, 672) │          0 │ block5c_activati… │
# │ (Multiply)          │                   │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 8, 8, 112) │     75,264 │ block5c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 8, 8, 112) │        448 │ block5c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 8, 8, 112) │          0 │ block5c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 8, 8, 112) │          0 │ block5c_drop[0][… │
# │                     │                   │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 8, 8, 672) │     75,264 │ block5c_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 8, 8, 672) │      2,688 │ block6a_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 8, 8, 672) │          0 │ block6a_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv_pad  │ (None, 11, 11,    │          0 │ block6a_expand_a… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv      │ (None, 4, 4, 672) │     16,800 │ block6a_dwconv_p… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 4, 4, 672) │      2,688 │ block6a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 4, 4, 672) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 672)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 672) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 672) │     19,488 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 4, 4, 672) │          0 │ block6a_activati… │
# │ (Multiply)          │                   │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 4, 4, 192) │    129,024 │ block6a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 4, 4, 192) │        768 │ block6a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 4, 4,      │    221,184 │ block6a_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 4, 4,      │      4,608 │ block6b_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 4, 4,      │          0 │ block6b_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv      │ (None, 4, 4,      │     28,800 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 4, 4,      │      4,608 │ block6b_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 4, 4,      │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 1152)      │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1,      │          0 │ block6b_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1,      │     56,448 │ block6b_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 4, 4,      │          0 │ block6b_activati… │
# │ (Multiply)          │ 1152)             │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 4, 4, 192) │    221,184 │ block6b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 4, 4, 192) │        768 │ block6b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 4, 4, 192) │          0 │ block6b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 4, 4, 192) │          0 │ block6b_drop[0][… │
# │                     │                   │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 4, 4,      │    221,184 │ block6b_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 4, 4,      │      4,608 │ block6c_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 4, 4,      │          0 │ block6c_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv      │ (None, 4, 4,      │     28,800 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 4, 4,      │      4,608 │ block6c_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 4, 4,      │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 1152)      │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1,      │          0 │ block6c_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1,      │     56,448 │ block6c_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 4, 4,      │          0 │ block6c_activati… │
# │ (Multiply)          │ 1152)             │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 4, 4, 192) │    221,184 │ block6c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 4, 4, 192) │        768 │ block6c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 4, 4, 192) │          0 │ block6c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 4, 4, 192) │          0 │ block6c_drop[0][… │
# │                     │                   │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 4, 4,      │    221,184 │ block6c_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 4, 4,      │      4,608 │ block6d_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 4, 4,      │          0 │ block6d_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv      │ (None, 4, 4,      │     28,800 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 4, 4,      │      4,608 │ block6d_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 4, 4,      │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 1152)      │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1,      │          0 │ block6d_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1,      │     56,448 │ block6d_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 4, 4,      │          0 │ block6d_activati… │
# │ (Multiply)          │ 1152)             │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 4, 4, 192) │    221,184 │ block6d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 4, 4, 192) │        768 │ block6d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 4, 4, 192) │          0 │ block6d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 4, 4, 192) │          0 │ block6d_drop[0][… │
# │                     │                   │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_conv │ (None, 4, 4,      │    221,184 │ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 4, 4,      │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 4, 4,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 4, 4,      │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 4, 4,      │      4,608 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 4, 4,      │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 4, 4,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 4, 4, 320) │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 4, 4, 320) │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 4, 4,      │    409,600 │ block7a_project_… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 4, 4,      │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 4, 4,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 8)         │     10,248 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,059,819 (15.49 MB)
#  Trainable params: 10,248 (40.03 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 705ms/step - accuracy: 0.2530 - loss: 2.1009 - val_accuracy: 0.4915 - val_loss: 1.6057 - learning_rate: 0.0010
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 467ms/step - accuracy: 0.5432 - loss: 1.5143 - val_accuracy: 0.7458 - val_loss: 1.2034 - learning_rate: 0.0010
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 493ms/step - accuracy: 0.7009 - loss: 1.1940 - val_accuracy: 0.8644 - val_loss: 0.9367 - learning_rate: 0.0010
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 542ms/step - accuracy: 0.8296 - loss: 0.8642 - val_accuracy: 0.9322 - val_loss: 0.7418 - learning_rate: 0.0010
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 419ms/step - accuracy: 0.8675 - loss: 0.7199 - val_accuracy: 0.9492 - val_loss: 0.6214 - learning_rate: 0.0010
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 522ms/step - accuracy: 0.9388 - loss: 0.5274 - val_accuracy: 0.9492 - val_loss: 0.5426 - learning_rate: 0.0010
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 412ms/step - accuracy: 0.9094 - loss: 0.5307 - val_accuracy: 0.9492 - val_loss: 0.4853 - learning_rate: 0.0010
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 463ms/step - accuracy: 0.9405 - loss: 0.4522 - val_accuracy: 0.9492 - val_loss: 0.4376 - learning_rate: 0.0010
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 512ms/step - accuracy: 0.9386 - loss: 0.4016 - val_accuracy: 0.9492 - val_loss: 0.4069 - learning_rate: 0.0010
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 494ms/step - accuracy: 0.9495 - loss: 0.3736 - val_accuracy: 0.9492 - val_loss: 0.3727 - learning_rate: 0.0010
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 426ms/step - accuracy: 0.9573 - loss: 0.3388 - val_accuracy: 0.9492 - val_loss: 0.3498 - learning_rate: 0.0010
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 568ms/step - accuracy: 0.9672 - loss: 0.2638 - val_accuracy: 0.9492 - val_loss: 0.3367 - learning_rate: 0.0010
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 420ms/step - accuracy: 0.9450 - loss: 0.3159 - val_accuracy: 0.9492 - val_loss: 0.3313 - learning_rate: 0.0010
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 505ms/step - accuracy: 0.9743 - loss: 0.2484 - val_accuracy: 0.9492 - val_loss: 0.3151 - learning_rate: 0.0010
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 417ms/step - accuracy: 0.9484 - loss: 0.2863 - val_accuracy: 0.9492 - val_loss: 0.2978 - learning_rate: 0.0010
# 1단계 (frozen base) Validation Accuracy: 0.9491525292396545

# %%
# EfficientNet 일부 레이어만 풀어서 미세조정
base_model.trainable = True

# 너무 많이 풀면 과적합이라 끝에서 몇 개 블록만 학습
fine_tune_at = len(base_model.layers) - 40  # 맨 끝 40개 레이어만 풀기

for i, layer in enumerate(base_model.layers):
    layer.trainable = (i >= fine_tune_at)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

es2 = EarlyStopping(
    monitor="val_accuracy",
    patience=10,
    restore_best_weights=True
)

history_ft = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=30,
    batch_size=16,
    callbacks=[es2],
    verbose=1
)

val_loss, val_acc = model.evaluate(x_val, y_val, verbose=0)
print("파인튜닝 후 Validation Accuracy:", val_acc)
# Out:
# Epoch 1/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 31s 839ms/step - accuracy: 0.6964 - loss: 1.0834 - val_accuracy: 0.9492 - val_loss: 0.5936
# Epoch 2/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 598ms/step - accuracy: 0.7545 - loss: 1.0669 - val_accuracy: 0.9492 - val_loss: 0.5784
# Epoch 3/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 590ms/step - accuracy: 0.6722 - loss: 1.0938 - val_accuracy: 0.9492 - val_loss: 0.5728
# Epoch 4/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 627ms/step - accuracy: 0.6869 - loss: 1.1075 - val_accuracy: 0.9322 - val_loss: 0.5707
# Epoch 5/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 663ms/step - accuracy: 0.7431 - loss: 0.9671 - val_accuracy: 0.9153 - val_loss: 0.5720
# Epoch 6/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 680ms/step - accuracy: 0.8083 - loss: 0.8960 - val_accuracy: 0.9153 - val_loss: 0.5745
# Epoch 7/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 535ms/step - accuracy: 0.7687 - loss: 0.9710 - val_accuracy: 0.9153 - val_loss: 0.5785
# Epoch 8/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 630ms/step - accuracy: 0.8173 - loss: 0.8822 - val_accuracy: 0.9153 - val_loss: 0.5838
# Epoch 9/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 707ms/step - accuracy: 0.8117 - loss: 0.8767 - val_accuracy: 0.9153 - val_loss: 0.5884
# Epoch 10/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 556ms/step - accuracy: 0.7775 - loss: 0.8881 - val_accuracy: 0.9153 - val_loss: 0.5889
# Epoch 11/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 562ms/step - accuracy: 0.8242 - loss: 0.7906 - val_accuracy: 0.9153 - val_loss: 0.5888
# 파인튜닝 후 Validation Accuracy: 0.9491525292396545

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.preprocessing import LabelEncoder  # 이미 위에서 le 만들었으면 이 줄은 생략

# 이미 위에서: le, model, IMG_SIZE 정의되어 있고,
# train 전처리 때 썼던 x 채널/리사이즈 방식 그대로 재사용해야 함.

# 1) test.npz 로드 + 전처리
test_data = np.load("test.npz")
x_test = test_data["x"].astype("float32")

if x_test.ndim == 3:
    x_test = x_test[..., np.newaxis]
if x_test.shape[-1] == 1:
    x_test = np.repeat(x_test, 3, axis=-1)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

# 2) 예측
probs = model.predict(x_test)
pred_idx = probs.argmax(axis=1)
pred_labels = le.inverse_transform(pred_idx)  # 숫자 -> 포켓몬 이름

# 3) submission.csv에 result 채우기
df = pd.read_csv("submission.csv")
df.dropna(axis=1, inplace=True)

df["result"] = pred_labels
df.to_csv("new_submission.csv", index=False)

print("✅ new_submission.csv 저장 완료")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step
# ✅ new_submission.csv 저장 완료

# %% [markdown]
# #3트

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ============================================
# 1. 데이터 로드
# ============================================
print("1. 데이터 로드 중...")
try:
    train_data = np.load("train.npz")
    x_train_full = train_data['x']
    y_train_full = train_data['y']   # 문자 라벨 (예: 'Abra')

    test_data = np.load("test.npz")
    x_test = test_data['x']

    df_submission = pd.read_csv("submission.csv")

    if 'pokemon' in df_submission.columns:
        result_col = 'pokemon'
    else:
        result_col = 'result'

    print(f"데이터 로드 완료. 예측은 '{result_col}' 컬럼에 기록됩니다.")

except FileNotFoundError as e:
    print(f"파일 오류: {e}")
    exit()

print(f"총 클래스 개수: {len(np.unique(y_train_full))}")
print(f"학습 샘플: {x_train_full.shape[0]}, 테스트 샘플: {x_test.shape[0]}")
print(f"이미지 shape: {x_train_full.shape[1:]}")

# ============================================
# 2. 전처리
# ============================================

# A. 정규화
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# B. 채널 맞추기
image_shape = x_train_full.shape[1:]
if len(image_shape) == 2:  # (H,W)
    x_train_full = np.expand_dims(x_train_full, axis=-1)
    x_test = np.expand_dims(x_test, axis=-1)
    input_shape = x_train_full.shape[1:]
else:
    input_shape = image_shape

print("CNN input shape:", input_shape)

# 🟡 C. 가장 중요한 부분: 문자 라벨 → 숫자 라벨 변환
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_train_full)

print("라벨 인코딩 예시:", list(zip(y_train_full[:5], y_encoded[:5])))
num_classes = len(label_encoder.classes_)

# 원-핫 인코딩
y_onehot = to_categorical(y_encoded, num_classes=num_classes)

# D. train/validation split
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full,
    y_onehot,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

print("train/val 분할 완료:", x_train.shape, x_val.shape)

# ============================================
# 3. 데이터 증강
# ============================================

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)

train_generator = datagen.flow(x_train, y_train, batch_size=32)

# ============================================
# 4. CNN 모델 구성
# ============================================

def create_cnn(input_shape, num_classes):
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        MaxPooling2D(2,2),
        Dropout(0.25),

        Conv2D(64, (3,3), activation='relu'),
        MaxPooling2D(2,2),
        Dropout(0.25),

        Conv2D(128, (3,3), activation='relu'),
        MaxPooling2D(2,2),
        Dropout(0.3),

        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

model = create_cnn(input_shape, num_classes)

model.compile(
    optimizer=Adam(0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# ============================================
# 5. 모델 학습
# ============================================

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

history = model.fit(
    train_generator,
    steps_per_epoch=len(x_train) // 32,
    epochs=150,
    validation_data=(x_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

val_loss, val_acc = model.evaluate(x_val, y_val, verbose=0)
print(f"\n검증 정확도: {val_acc:.4f}")

# ============================================
# 6. 제출 파일 생성
# ============================================

# test 데이터 예측
y_pred_onehot = model.predict(x_test)
y_pred_idx = np.argmax(y_pred_onehot, axis=1)

# 숫자 → 원래 포켓몬 이름으로 변환
y_pred_labels = label_encoder.inverse_transform(y_pred_idx)

df_submission[result_col] = y_pred_labels

submission_file = "my_submission_xai_05.csv"
df_submission.to_csv(submission_file, index=False)

print(f"\n✅ 제출 파일 생성 완료: {submission_file}")
# Out:
# 1. 데이터 로드 중...
# 데이터 로드 완료. 예측은 'pokemon' 컬럼에 기록됩니다.
# 총 클래스 개수: 8
# 학습 샘플: 292, 테스트 샘플: 73
# 이미지 shape: (200, 200, 3)
# CNN input shape: (200, 200, 3)
# 라벨 인코딩 예시: [(np.str_('Abra'), np.int64(0)), (np.str_('Eevee'), np.int64(4)), (np.str_('Bulbasaur'), np.int64(2)), (np.str_('Arcanine'), np.int64(1)), (np.str_('Arcanine'), np.int64(1))]
# train/val 분할 완료: (233, 200, 200, 3) (59, 200, 200, 3)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 198, 198, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 99, 99, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 99, 99, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 97, 97, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 46, 46, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 23, 23, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 23, 23, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 67712)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    34,669,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         4,104 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,766,408 (132.62 MB)
#  Trainable params: 34,766,408 (132.62 MB)
#  Non-trainable params: 0 (0.00 B)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.1167 - loss: 8.8902 - val_accuracy: 0.1356 - val_loss: 2.0786 - learning_rate: 0.0010
# Epoch 2/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0938 - loss: 2.1143 - val_accuracy: 0.1356 - val_loss: 2.0789 - learning_rate: 0.0010
# Epoch 3/150
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 362ms/step - accuracy: 0.1680 - loss: 2.0745 - val_accuracy: 0.1695 - val_loss: 2.0548 - learning_rate: 0.0010
# Epoch 4/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2188 - loss: 2.0243 - val_accuracy: 0.1695 - val_loss: 2.0517 - learning_rate: 0.0010
# Epoch 5/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - accuracy: 0.1489 - loss: 2.0475 - val_accuracy: 0.1864 - val_loss: 2.0206 - learning_rate: 0.0010
# Epoch 6/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1250 - loss: 2.0265 - val_accuracy: 0.2881 - val_loss: 2.0172 - learning_rate: 0.0010
# Epoch 7/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - accuracy: 0.1908 - loss: 1.9895 - val_accuracy: 0.2881 - val_loss: 1.9785 - learning_rate: 0.0010
# Epoch 8/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2812 - loss: 1.9414 - val_accuracy: 0.2712 - val_loss: 1.9665 - learning_rate: 0.0010
# Epoch 9/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - accuracy: 0.3487 - loss: 1.7777 - val_accuracy: 0.3390 - val_loss: 1.7981 - learning_rate: 0.0010
# Epoch 10/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2500 - loss: 1.9263 - val_accuracy: 0.3559 - val_loss: 1.6913 - learning_rate: 0.0010
# Epoch 11/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 0.3348 - loss: 1.5771 - val_accuracy: 0.4068 - val_loss: 1.4139 - learning_rate: 0.0010
# Epoch 12/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3125 - loss: 1.5139 - val_accuracy: 0.4407 - val_loss: 1.3575 - learning_rate: 0.0010
# Epoch 13/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 283ms/step - accuracy: 0.3795 - loss: 1.4237 - val_accuracy: 0.5763 - val_loss: 1.2100 - learning_rate: 0.0010
# Epoch 14/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3750 - loss: 1.1783 - val_accuracy: 0.5254 - val_loss: 1.1799 - learning_rate: 0.0010
# Epoch 15/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 287ms/step - accuracy: 0.5221 - loss: 1.2403 - val_accuracy: 0.5763 - val_loss: 1.1001 - learning_rate: 0.0010
# Epoch 16/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5312 - loss: 1.0891 - val_accuracy: 0.5932 - val_loss: 1.0679 - learning_rate: 0.0010
# Epoch 17/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - accuracy: 0.5269 - loss: 1.1695 - val_accuracy: 0.5763 - val_loss: 1.0992 - learning_rate: 0.0010
# Epoch 18/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5938 - loss: 0.9904 - val_accuracy: 0.5932 - val_loss: 1.0622 - learning_rate: 0.0010
# Epoch 19/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 299ms/step - accuracy: 0.6172 - loss: 0.9837 - val_accuracy: 0.6780 - val_loss: 0.9802 - learning_rate: 0.0010
# Epoch 20/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6562 - loss: 0.9749 - val_accuracy: 0.6271 - val_loss: 0.9986 - learning_rate: 0.0010
# Epoch 21/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 401ms/step - accuracy: 0.6439 - loss: 0.8780 - val_accuracy: 0.6271 - val_loss: 0.8587 - learning_rate: 0.0010
# Epoch 22/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6875 - loss: 0.8161 - val_accuracy: 0.6271 - val_loss: 0.8423 - learning_rate: 0.0010
# Epoch 23/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 292ms/step - accuracy: 0.6378 - loss: 0.8864 - val_accuracy: 0.6949 - val_loss: 0.8146 - learning_rate: 0.0010
# Epoch 24/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5938 - loss: 0.8608 - val_accuracy: 0.6610 - val_loss: 0.7923 - learning_rate: 0.0010
# Epoch 25/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 287ms/step - accuracy: 0.6565 - loss: 0.7755 - val_accuracy: 0.6949 - val_loss: 0.8095 - learning_rate: 0.0010
# Epoch 26/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5556 - loss: 0.7767 - val_accuracy: 0.7119 - val_loss: 0.8018 - learning_rate: 0.0010
# Epoch 27/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - accuracy: 0.7611 - loss: 0.6715 - val_accuracy: 0.7458 - val_loss: 0.7107 - learning_rate: 0.0010
# Epoch 28/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6562 - loss: 0.8698 - val_accuracy: 0.7627 - val_loss: 0.7213 - learning_rate: 0.0010
# Epoch 29/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - accuracy: 0.7633 - loss: 0.6085 - val_accuracy: 0.8136 - val_loss: 0.6545 - learning_rate: 0.0010
# Epoch 30/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7778 - loss: 0.4125 - val_accuracy: 0.8305 - val_loss: 0.6596 - learning_rate: 0.0010
# Epoch 31/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - accuracy: 0.7415 - loss: 0.7521 - val_accuracy: 0.7627 - val_loss: 0.7778 - learning_rate: 0.0010
# Epoch 32/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8125 - loss: 0.4219 - val_accuracy: 0.7627 - val_loss: 0.7691 - learning_rate: 0.0010
# Epoch 33/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - accuracy: 0.8247 - loss: 0.5350 - val_accuracy: 0.7458 - val_loss: 0.6759 - learning_rate: 0.0010
# Epoch 34/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8125 - loss: 0.6833 - val_accuracy: 0.7627 - val_loss: 0.7562 - learning_rate: 0.0010
# Epoch 35/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - accuracy: 0.7046 - loss: 0.7589 - val_accuracy: 0.7966 - val_loss: 0.6665 - learning_rate: 2.0000e-04
# Epoch 36/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.2826 - val_accuracy: 0.7966 - val_loss: 0.6681 - learning_rate: 2.0000e-04
# Epoch 37/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - accuracy: 0.7798 - loss: 0.5729 - val_accuracy: 0.8305 - val_loss: 0.6198 - learning_rate: 2.0000e-04
# Epoch 38/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7778 - loss: 0.4716 - val_accuracy: 0.8305 - val_loss: 0.6157 - learning_rate: 2.0000e-04
# Epoch 39/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 363ms/step - accuracy: 0.8201 - loss: 0.5507 - val_accuracy: 0.7966 - val_loss: 0.5949 - learning_rate: 2.0000e-04
# Epoch 40/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7812 - loss: 0.5969 - val_accuracy: 0.7966 - val_loss: 0.5901 - learning_rate: 2.0000e-04
# Epoch 41/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 327ms/step - accuracy: 0.8329 - loss: 0.4640 - val_accuracy: 0.7966 - val_loss: 0.5589 - learning_rate: 2.0000e-04
# Epoch 42/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8750 - loss: 0.3956 - val_accuracy: 0.8136 - val_loss: 0.5582 - learning_rate: 2.0000e-04
# Epoch 43/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.8436 - loss: 0.4097 - val_accuracy: 0.8305 - val_loss: 0.5812 - learning_rate: 2.0000e-04
# Epoch 44/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8125 - loss: 0.5391 - val_accuracy: 0.8136 - val_loss: 0.5838 - learning_rate: 2.0000e-04
# Epoch 45/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - accuracy: 0.8322 - loss: 0.4599 - val_accuracy: 0.8136 - val_loss: 0.5857 - learning_rate: 2.0000e-04
# Epoch 46/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7500 - loss: 0.5527 - val_accuracy: 0.8136 - val_loss: 0.5861 - learning_rate: 2.0000e-04
# Epoch 47/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.8485 - loss: 0.4440 - val_accuracy: 0.8136 - val_loss: 0.5928 - learning_rate: 2.0000e-04
# Epoch 48/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9062 - loss: 0.2387 - val_accuracy: 0.8136 - val_loss: 0.5927 - learning_rate: 1.0000e-04
# Epoch 49/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.8364 - loss: 0.4819 - val_accuracy: 0.8475 - val_loss: 0.5880 - learning_rate: 1.0000e-04
# Epoch 50/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8750 - loss: 0.4510 - val_accuracy: 0.8305 - val_loss: 0.5856 - learning_rate: 1.0000e-04
# Epoch 51/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - accuracy: 0.8535 - loss: 0.3665 - val_accuracy: 0.8305 - val_loss: 0.5704 - learning_rate: 1.0000e-04
# Epoch 52/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.1398 - val_accuracy: 0.8136 - val_loss: 0.5676 - learning_rate: 1.0000e-04
# Epoch 53/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 331ms/step - accuracy: 0.8686 - loss: 0.4113 - val_accuracy: 0.8305 - val_loss: 0.5562 - learning_rate: 1.0000e-04
# Epoch 54/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8125 - loss: 0.4932 - val_accuracy: 0.8305 - val_loss: 0.5569 - learning_rate: 1.0000e-04
# Epoch 55/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - accuracy: 0.8317 - loss: 0.4318 - val_accuracy: 0.8475 - val_loss: 0.5790 - learning_rate: 1.0000e-04
# Epoch 56/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3377 - val_accuracy: 0.8475 - val_loss: 0.5823 - learning_rate: 1.0000e-04
# Epoch 57/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.8439 - loss: 0.4422 - val_accuracy: 0.8475 - val_loss: 0.5802 - learning_rate: 1.0000e-04
# Epoch 58/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8438 - loss: 0.3911 - val_accuracy: 0.8475 - val_loss: 0.5799 - learning_rate: 1.0000e-04
# Epoch 59/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 294ms/step - accuracy: 0.8383 - loss: 0.5290 - val_accuracy: 0.8475 - val_loss: 0.5812 - learning_rate: 1.0000e-04
# Epoch 60/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8750 - loss: 0.3853 - val_accuracy: 0.8475 - val_loss: 0.5814 - learning_rate: 1.0000e-04
# Epoch 61/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 397ms/step - accuracy: 0.8503 - loss: 0.4248 - val_accuracy: 0.8475 - val_loss: 0.5681 - learning_rate: 1.0000e-04
# Epoch 62/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.4153 - val_accuracy: 0.8475 - val_loss: 0.5652 - learning_rate: 1.0000e-04
# Epoch 63/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.8763 - loss: 0.3933 - val_accuracy: 0.8305 - val_loss: 0.5569 - learning_rate: 1.0000e-04
# Epoch 64/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9375 - loss: 0.3719 - val_accuracy: 0.8305 - val_loss: 0.5570 - learning_rate: 1.0000e-04
# Epoch 65/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.8361 - loss: 0.4314 - val_accuracy: 0.8475 - val_loss: 0.5685 - learning_rate: 1.0000e-04
# Epoch 66/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.2734 - val_accuracy: 0.8475 - val_loss: 0.5688 - learning_rate: 1.0000e-04
# Epoch 67/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - accuracy: 0.8929 - loss: 0.3339 - val_accuracy: 0.8305 - val_loss: 0.5849 - learning_rate: 1.0000e-04
# Epoch 68/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8125 - loss: 0.5718 - val_accuracy: 0.8305 - val_loss: 0.5885 - learning_rate: 1.0000e-04
# Epoch 69/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - accuracy: 0.8436 - loss: 0.4204 - val_accuracy: 0.8475 - val_loss: 0.5765 - learning_rate: 1.0000e-04
# Epoch 70/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3092 - val_accuracy: 0.8475 - val_loss: 0.5735 - learning_rate: 1.0000e-04
# Epoch 71/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 387ms/step - accuracy: 0.8164 - loss: 0.4973 - val_accuracy: 0.8475 - val_loss: 0.5557 - learning_rate: 1.0000e-04
# Epoch 72/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8438 - loss: 0.3986 - val_accuracy: 0.8644 - val_loss: 0.5545 - learning_rate: 1.0000e-04
# Epoch 73/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.8950 - loss: 0.3393 - val_accuracy: 0.8644 - val_loss: 0.5590 - learning_rate: 1.0000e-04
# Epoch 74/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8438 - loss: 0.4761 - val_accuracy: 0.8644 - val_loss: 0.5599 - learning_rate: 1.0000e-04
# Epoch 75/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.8848 - loss: 0.4034 - val_accuracy: 0.8644 - val_loss: 0.5589 - learning_rate: 1.0000e-04
# Epoch 76/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.1604 - val_accuracy: 0.8644 - val_loss: 0.5592 - learning_rate: 1.0000e-04
# Epoch 77/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.9228 - loss: 0.2839 - val_accuracy: 0.8644 - val_loss: 0.5573 - learning_rate: 1.0000e-04
# Epoch 78/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8125 - loss: 0.4655 - val_accuracy: 0.8644 - val_loss: 0.5561 - learning_rate: 1.0000e-04
# Epoch 79/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - accuracy: 0.9098 - loss: 0.3437 - val_accuracy: 0.8644 - val_loss: 0.5435 - learning_rate: 1.0000e-04
# Epoch 80/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9062 - loss: 0.2171 - val_accuracy: 0.8644 - val_loss: 0.5437 - learning_rate: 1.0000e-04
# Epoch 81/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 411ms/step - accuracy: 0.9038 - loss: 0.2992 - val_accuracy: 0.8644 - val_loss: 0.5467 - learning_rate: 1.0000e-04
# Epoch 82/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8889 - loss: 0.2426 - val_accuracy: 0.8644 - val_loss: 0.5472 - learning_rate: 1.0000e-04
# Epoch 83/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - accuracy: 0.9109 - loss: 0.3682 - val_accuracy: 0.8644 - val_loss: 0.5466 - learning_rate: 1.0000e-04
# Epoch 84/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8438 - loss: 0.4264 - val_accuracy: 0.8644 - val_loss: 0.5464 - learning_rate: 1.0000e-04
# Epoch 85/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - accuracy: 0.8406 - loss: 0.4852 - val_accuracy: 0.8644 - val_loss: 0.5415 - learning_rate: 1.0000e-04
# Epoch 86/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8438 - loss: 0.3893 - val_accuracy: 0.8644 - val_loss: 0.5391 - learning_rate: 1.0000e-04
# Epoch 87/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - accuracy: 0.9143 - loss: 0.2364 - val_accuracy: 0.8475 - val_loss: 0.5360 - learning_rate: 1.0000e-04
# Epoch 88/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.3967 - val_accuracy: 0.8475 - val_loss: 0.5390 - learning_rate: 1.0000e-04
# Epoch 89/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.8740 - loss: 0.4122 - val_accuracy: 0.8305 - val_loss: 0.5784 - learning_rate: 1.0000e-04
# Epoch 90/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8125 - loss: 0.4499 - val_accuracy: 0.8305 - val_loss: 0.5786 - learning_rate: 1.0000e-04
# Epoch 91/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - accuracy: 0.8318 - loss: 0.3857 - val_accuracy: 0.8475 - val_loss: 0.5471 - learning_rate: 1.0000e-04
# Epoch 92/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9062 - loss: 0.2284 - val_accuracy: 0.8305 - val_loss: 0.5410 - learning_rate: 1.0000e-04
# Epoch 93/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.8951 - loss: 0.2873 - val_accuracy: 0.8475 - val_loss: 0.5312 - learning_rate: 1.0000e-04
# Epoch 94/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3965 - val_accuracy: 0.8475 - val_loss: 0.5345 - learning_rate: 1.0000e-04
# Epoch 95/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - accuracy: 0.9067 - loss: 0.2750 - val_accuracy: 0.8475 - val_loss: 0.5757 - learning_rate: 1.0000e-04
# Epoch 96/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0351 - val_accuracy: 0.8475 - val_loss: 0.5758 - learning_rate: 1.0000e-04
# Epoch 97/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.8813 - loss: 0.3346 - val_accuracy: 0.8644 - val_loss: 0.5423 - learning_rate: 1.0000e-04
# Epoch 98/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.1805 - val_accuracy: 0.8644 - val_loss: 0.5355 - learning_rate: 1.0000e-04
# Epoch 99/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 412ms/step - accuracy: 0.9152 - loss: 0.2848 - val_accuracy: 0.8644 - val_loss: 0.5231 - learning_rate: 1.0000e-04
# Epoch 100/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9375 - loss: 0.2792 - val_accuracy: 0.8644 - val_loss: 0.5236 - learning_rate: 1.0000e-04
# Epoch 101/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.9081 - loss: 0.2404 - val_accuracy: 0.8644 - val_loss: 0.5380 - learning_rate: 1.0000e-04
# Epoch 102/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8125 - loss: 0.4232 - val_accuracy: 0.8644 - val_loss: 0.5413 - learning_rate: 1.0000e-04
# Epoch 103/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - accuracy: 0.8895 - loss: 0.3888 - val_accuracy: 0.8475 - val_loss: 0.5493 - learning_rate: 1.0000e-04
# Epoch 104/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.1301 - val_accuracy: 0.8475 - val_loss: 0.5464 - learning_rate: 1.0000e-04
# Epoch 105/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - accuracy: 0.8683 - loss: 0.3864 - val_accuracy: 0.8305 - val_loss: 0.5508 - learning_rate: 1.0000e-04
# Epoch 106/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.2431 - val_accuracy: 0.8305 - val_loss: 0.5522 - learning_rate: 1.0000e-04
# Epoch 107/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step - accuracy: 0.8940 - loss: 0.2950 - val_accuracy: 0.8305 - val_loss: 0.5578 - learning_rate: 1.0000e-04
# Epoch 108/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7812 - loss: 0.5822 - val_accuracy: 0.8305 - val_loss: 0.5595 - learning_rate: 1.0000e-04
# Epoch 109/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - accuracy: 0.8888 - loss: 0.2844 - val_accuracy: 0.8644 - val_loss: 0.5459 - learning_rate: 1.0000e-04
# Epoch 110/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.2667 - val_accuracy: 0.8814 - val_loss: 0.5436 - learning_rate: 1.0000e-04
# Epoch 111/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9054 - loss: 0.2676 - val_accuracy: 0.8644 - val_loss: 0.5357 - learning_rate: 1.0000e-04
# Epoch 112/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8438 - loss: 0.4310 - val_accuracy: 0.8644 - val_loss: 0.5363 - learning_rate: 1.0000e-04
# Epoch 113/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 282ms/step - accuracy: 0.9043 - loss: 0.3081 - val_accuracy: 0.8644 - val_loss: 0.5268 - learning_rate: 1.0000e-04
# Epoch 114/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.1137 - val_accuracy: 0.8814 - val_loss: 0.5248 - learning_rate: 1.0000e-04
# Epoch 115/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 281ms/step - accuracy: 0.9204 - loss: 0.3176 - val_accuracy: 0.8814 - val_loss: 0.5288 - learning_rate: 1.0000e-04
# Epoch 116/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0685 - val_accuracy: 0.8814 - val_loss: 0.5315 - learning_rate: 1.0000e-04
# Epoch 117/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 0.9119 - loss: 0.2918 - val_accuracy: 0.8644 - val_loss: 0.5334 - learning_rate: 1.0000e-04
# Epoch 118/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9062 - loss: 0.2529 - val_accuracy: 0.8644 - val_loss: 0.5327 - learning_rate: 1.0000e-04
# Epoch 119/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - accuracy: 0.8800 - loss: 0.2894 - val_accuracy: 0.8644 - val_loss: 0.5182 - learning_rate: 1.0000e-04
# Epoch 120/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9375 - loss: 0.2302 - val_accuracy: 0.8644 - val_loss: 0.5166 - learning_rate: 1.0000e-04
# Epoch 121/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - accuracy: 0.9056 - loss: 0.2827 - val_accuracy: 0.8644 - val_loss: 0.5097 - learning_rate: 1.0000e-04
# Epoch 122/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9062 - loss: 0.2712 - val_accuracy: 0.8644 - val_loss: 0.5084 - learning_rate: 1.0000e-04
# Epoch 123/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - accuracy: 0.9348 - loss: 0.2456 - val_accuracy: 0.8305 - val_loss: 0.4996 - learning_rate: 1.0000e-04
# Epoch 124/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9375 - loss: 0.2443 - val_accuracy: 0.8305 - val_loss: 0.4998 - learning_rate: 1.0000e-04
# Epoch 125/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - accuracy: 0.8692 - loss: 0.3617 - val_accuracy: 0.8475 - val_loss: 0.4951 - learning_rate: 1.0000e-04
# Epoch 126/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0964 - val_accuracy: 0.8475 - val_loss: 0.4939 - learning_rate: 1.0000e-04
# Epoch 127/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 0.8858 - loss: 0.3148 - val_accuracy: 0.8644 - val_loss: 0.5060 - learning_rate: 1.0000e-04
# Epoch 128/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.8644 - val_loss: 0.5059 - learning_rate: 1.0000e-04
# Epoch 129/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - accuracy: 0.9134 - loss: 0.2316 - val_accuracy: 0.8814 - val_loss: 0.5030 - learning_rate: 1.0000e-04
# Epoch 130/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8438 - loss: 0.3842 - val_accuracy: 0.8814 - val_loss: 0.5028 - learning_rate: 1.0000e-04
# Epoch 131/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - accuracy: 0.8889 - loss: 0.2851 - val_accuracy: 0.8814 - val_loss: 0.5059 - learning_rate: 1.0000e-04
# Epoch 132/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9062 - loss: 0.1928 - val_accuracy: 0.8814 - val_loss: 0.5076 - learning_rate: 1.0000e-04
# Epoch 133/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - accuracy: 0.9077 - loss: 0.2349 - val_accuracy: 0.8475 - val_loss: 0.5168 - learning_rate: 1.0000e-04
# Epoch 134/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7812 - loss: 0.5452 - val_accuracy: 0.8475 - val_loss: 0.5147 - learning_rate: 1.0000e-04
# Epoch 135/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - accuracy: 0.8704 - loss: 0.2912 - val_accuracy: 0.8814 - val_loss: 0.5054 - learning_rate: 1.0000e-04
# Epoch 136/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8889 - loss: 0.3389 - val_accuracy: 0.8814 - val_loss: 0.5045 - learning_rate: 1.0000e-04
# Epoch 137/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - accuracy: 0.9435 - loss: 0.2381 - val_accuracy: 0.8814 - val_loss: 0.5011 - learning_rate: 1.0000e-04
# Epoch 138/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8889 - loss: 0.3208 - val_accuracy: 0.8814 - val_loss: 0.5030 - learning_rate: 1.0000e-04
# Epoch 139/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 391ms/step - accuracy: 0.9418 - loss: 0.2220 - val_accuracy: 0.8644 - val_loss: 0.5218 - learning_rate: 1.0000e-04
# Epoch 140/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8438 - loss: 0.3825 - val_accuracy: 0.8814 - val_loss: 0.5265 - learning_rate: 1.0000e-04
# Epoch 141/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - accuracy: 0.8887 - loss: 0.2640 - val_accuracy: 0.8475 - val_loss: 0.5338 - learning_rate: 1.0000e-04
# Epoch 142/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3318 - val_accuracy: 0.8814 - val_loss: 0.5328 - learning_rate: 1.0000e-04
# Epoch 143/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - accuracy: 0.9006 - loss: 0.3247 - val_accuracy: 0.8644 - val_loss: 0.4941 - learning_rate: 1.0000e-04
# Epoch 144/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9062 - loss: 0.2682 - val_accuracy: 0.8644 - val_loss: 0.4914 - learning_rate: 1.0000e-04
# Epoch 145/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - accuracy: 0.9207 - loss: 0.2734 - val_accuracy: 0.8814 - val_loss: 0.4884 - learning_rate: 1.0000e-04
# Epoch 146/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.4486 - val_accuracy: 0.8814 - val_loss: 0.4890 - learning_rate: 1.0000e-04
# Epoch 147/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.8731 - loss: 0.2799 - val_accuracy: 0.8814 - val_loss: 0.5098 - learning_rate: 1.0000e-04
# Epoch 148/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.2643 - val_accuracy: 0.8814 - val_loss: 0.5139 - learning_rate: 1.0000e-04
# Epoch 149/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 363ms/step - accuracy: 0.8621 - loss: 0.3367 - val_accuracy: 0.8814 - val_loss: 0.5036 - learning_rate: 1.0000e-04
# Epoch 150/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9062 - loss: 0.2786 - val_accuracy: 0.8814 - val_loss: 0.5046 - learning_rate: 1.0000e-04
#
# 검증 정확도: 0.8814
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step
#
# ✅ 제출 파일 생성 완료: my_submission_xai_05.csv
